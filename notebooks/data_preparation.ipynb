# %%
# Import necessary libraries
import pandas as pd

# %%
# Load your Excel data clearly
data_path = '../data/meta_ads_cleaned.xlsx'
data = pd.read_excel(data_path)

# %%
# Check the first few rows clearly
data.head()
# Out:
#                                        Campaign name Campaign Delivery  \
# 0  SO/2024/0281 - Campagne Ramadan - Instagram - ...          inactive
# 1  SO/2024/0318  - Campagne Ramadan 2 - BC : - In...    not_delivering
# 2  SO/2024/0576 - Orange - Lancement posts digita...    not_delivering
# 3  SO/2024/0318  - Campagne Ramadan 2 - BC : - In...    not_delivering
# 4  SO/2024/0556 - Orange - Lancement_campagne_Dat...    not_delivering
#
#           Platforme   Device         Placement     Objective  \
# 0         Instagram   In-app              Feed     Awareness
# 1  Audience Network   In-app              Feed  App Installs
# 2  Audience Network   In-app              Feed         Sales
# 3  Audience Network   In-app  Facebook Stories  App Installs
# 4         Instagram  Desktop              Feed     Awareness
#
#                                Result indicator  Ad set budget  \
# 0                                         reach           0.28
# ...

# %%
# Check general info (types, columns, memory clearly)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 68 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Campaign name                                          572 non-null    object
#  1   Campaign Delivery                                      572 non-null    object
#  2   Platforme                                              572 non-null    object
#  3   Device                                                 572 non-null    object
#  4   Placement                                              572 non-null    object
#  5   Objective                                              572 non-null    object
#  6   Result indicator                                       572 non-null    object
#  7   Ad set budget                                          572 non-null    float64
# ...

# %%
# Get descriptive statistics (mean, median, std, clearly check for outliers or oddities)
data.describe()
# Out:
#        Ad set budget  Amount spent                   Date created  \
# count     572.000000    572.000000                            572
# mean      321.102745    322.441713  2024-07-08 16:44:28.531468544
# min         0.280000      0.280000            2023-11-28 00:00:00
# 25%        45.062500     45.680000            2024-03-11 00:00:00
# 50%       120.980000    121.690000            2024-06-28 00:00:00
# 75%       333.482500    340.147500            2024-11-05 00:00:00
# max      4614.530000   4614.530000            2025-04-11 00:00:00
# std       574.449407    574.092324                            NaN
#
#                               Starts         Reach   Impressions   Frequency  \
# count                            572  5.720000e+02  5.720000e+02  572.000000
# mean   2024-07-08 19:07:58.321678336  5.870390e+05  1.939894e+06    2.536131
# min              2023-11-28 00:00:00  1.090000e+03  1.090000e+03    1.000000
# ...

# %%
# Clearly verify no remaining missing values
data.isnull().sum()
# Out:
# Campaign name                           0
# Campaign Delivery                       0
# Platforme                               0
# Device                                  0
# Placement                               0
#                                        ..
# Checkouts initiated conversion value    0
# Cost per checkout initiated (USD)       0
# Landing page views                      0
# Cost per landing page view (USD)        0
# Cost per purchase (USD)                 0
# Length: 68, dtype: int64

# %%
# Save to CSV clearly
data.to_csv('../data/meta_ads_cleaned.csv', index=False)
